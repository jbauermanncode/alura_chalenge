# %%
import pandas as pd
import numpy as np

# %%
churn_de_clientes = pd.read_json('https://raw.githubusercontent.com/sthemonica/alura-voz/main/Dados/Telco-Customer-Churn.json')

# %%
churn_de_clientes.head(10)
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 5  0013-MHZWF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 6  0013-SMEOE    No  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 7  0014-BMAQU    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 8  0015-UOCOJ    No  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 9  0016-QLJIS    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# ...

# %%
len(churn_de_clientes)
# Out:
# 7267

# %%
type(churn_de_clientes)
# Out:
# pandas.core.frame.DataFrame

# %%
churn_de_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
churn_de_clientes.dtypes
# Out:
# customerID    object
# Churn         object
# customer      object
# phone         object
# internet      object
# account       object
# dtype: object

# %%
tipos_de_dados = pd.DataFrame(churn_de_clientes.dtypes, columns = ['Tipos de Dados'])

# %%
tipos_de_dados.columns.name = 'Variáveis'

# %%
tipos_de_dados
# Out:
# Variáveis  Tipos de Dados
# customerID         object
# Churn              object
# customer           object
# phone              object
# internet           object
# account            object

# %%
churn_de_clientes.shape
# Out:
# (7267, 6)

# %%
print(f'Número de Variáveis: {churn_de_clientes.shape[1]} \nNúmero de IDs cadastrados: {churn_de_clientes.shape[0]}')
# Out:
# Número de Variáveis: 6
# Número de IDs cadastrados: 7267

# %%
churn_de_clientes.head(10)
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 5  0013-MHZWF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 6  0013-SMEOE    No  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 7  0014-BMAQU    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 8  0015-UOCOJ    No  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 9  0016-QLJIS    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# ...

# %%
yes = ['Yes']
selecao_yes = churn_de_clientes['Churn'].isin(yes)

# %%
churn_yes = churn_de_clientes[selecao_yes]

# %%
churn_yes.head(10)
# Out:
#     customerID Churn                                           customer  \
# 2   0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3   0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4   0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 18  0022-TCJCI   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 19  0023-HGHWL   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 21  0023-XUOPT   Yes  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 24  0031-PVLZI   Yes  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 25  0032-PGELS   Yes  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 41  0067-DKWBL   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 54  0093-XWZFY   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                 phone  \
# 2      {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3      {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...

# %%
no = ['No']
selecao_no = churn_de_clientes['Churn'].isin(no)

# %%
churn_no = churn_de_clientes[selecao_no]

# %%
churn_no.head(10)
# Out:
#     customerID Churn                                           customer  \
# 0   0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1   0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 5   0013-MHZWF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 6   0013-SMEOE    No  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 7   0014-BMAQU    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 8   0015-UOCOJ    No  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 9   0016-QLJIS    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 10  0017-DINOC    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 11  0017-IUDMW    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 12  0018-NYROU    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                 phone  \
# 0      {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1     {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# ...

# %%
coluna_churn = pd.DataFrame(churn_de_clientes['Churn'])

# %%
coluna_churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Churn   7267 non-null   object
# dtypes: object(1)
# memory usage: 56.9+ KB

# %%
churn_de_clientes[churn_de_clientes['Churn'].isnull()].shape[0]
# Out:
# 0

# %%
churn_de_clientes['Churn'].drop_duplicates()
# Out:
# 0      No
# 2     Yes
# 30
# Name: Churn, dtype: object

# %%
selecao_diferente = ((churn_de_clientes['Churn'] != 'Yes') & (churn_de_clientes['Churn'] != 'No'))

# %%
selecao_diferente
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7262    False
# 7263    False
# 7264    False
# 7265    False
# 7266    False
# Name: Churn, Length: 7267, dtype: bool

# %%
churn_diferente = churn_de_clientes[selecao_diferente]

# %%
churn_diferente
# Out:
#       customerID Churn                                           customer  \
# 30    0047-ZHDTW        {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 75    0120-YZLQA        {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 96    0154-QYHJU        {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 98    0162-RZGMZ        {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 175   0274-VVQOQ        {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# ...          ...   ...                                                ...
# 7158  9840-GSRFX        {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7180  9872-RZQQB        {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7211  9920-GNDMB        {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7239  9955-RVWSC        {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7247  9966-VYRTZ        {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                   phone  \
# ...

# %%
print(f'Total de clientes: {len(churn_de_clientes)}\nDesistência de clientes: {len(churn_yes)}\nPermanência de clientes: {len(churn_no)}\nCampo Vazio: {len(churn_diferente)}')
# Out:
# Total de clientes: 7267
# Desistência de clientes: 1869
# Permanência de clientes: 5174
# Campo Vazio: 224

# %%
churn_de_clientes.head(5)
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %% [markdown]
# # Separar Clientes

# %%
selecao_cliente = churn_de_clientes['customer']

# %%
selecao_cliente
# Out:
# 0       {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1       {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2       {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3       {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4       {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#                               ...
# 7262    {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# Name: customer, Length: 7267, dtype: object

# %% [markdown]
# ## Separar Clientes por genero

# %%
genero = [d['gender'] for d in selecao_cliente]

# %%
genero = pd.DataFrame(genero, columns = ['genero'])

# %%
genero
# Out:
#       genero
# 0     Female
# 1       Male
# 2       Male
# 3       Male
# 4     Female
# ...      ...
# 7262  Female
# 7263    Male
# 7264    Male
# 7265    Male
# 7266    Male
#
# [7267 rows x 1 columns]

# %%
female = ['Female']
feminino = genero['genero'].isin(female)

# %%
feminino = genero[feminino]

# %%
male = ['Male']
masculino = genero['genero'].isin(male)

# %%
masculino = genero[masculino]

# %%
len(masculino) + len(feminino)
# Out:
# 7267

# %%
print(f'Sexo Masculino: {len(masculino)}\nSexo Feminino: {len(feminino)}')
# Out:
# Sexo Masculino: 3675
# Sexo Feminino: 3592

# %% [markdown]
# ## Separar Clientes para saber se o cliente tem idade >= 65

# %%
idoso = [d['SeniorCitizen'] for d in selecao_cliente]

# %%
idoso = pd.DataFrame(idoso, columns = ['idoso'])

# %%
idoso_yes = idoso['idoso'].isin([True])

# %%
idoso_yes = idoso[idoso_yes]

# %%
idoso_yes
# Out:
#       idoso
# 3         1
# 4         1
# 6         1
# 8         1
# 17        1
# ...     ...
# 7243      1
# 7246      1
# 7251      1
# 7254      1
# 7258      1
#
# [1182 rows x 1 columns]

# %%
idoso_not = idoso['idoso'].isin([False])

# %%
idoso_not = idoso[idoso_not]

# %%
idoso_not
# Out:
#       idoso
# 0         0
# 1         0
# 2         0
# 5         0
# 7         0
# ...     ...
# 7262      0
# 7263      0
# 7264      0
# 7265      0
# 7266      0
#
# [6085 rows x 1 columns]

# %%
len(idoso_yes) + len(idoso_not)
# Out:
# 7267

# %%
print(f'Idade >= 65: {len(idoso_yes)}\nIdade < 65: {len(idoso_not)}')
# Out:
# Idade >= 65: 1182
# Idade < 65: 6085

# %% [markdown]
# ## Separar se cliente tem ou não parceiro

# %%
parceiro = [d['Partner'] for d in selecao_cliente]

# %%
parceiro = pd.DataFrame(parceiro, columns = ['parceiro'])

# %%
parceiro
# Out:
#      parceiro
# 0         Yes
# 1          No
# 2          No
# 3         Yes
# 4         Yes
# ...       ...
# 7262       No
# 7263      Yes
# 7264       No
# 7265      Yes
# 7266      Yes
#
# [7267 rows x 1 columns]

# %%
yes = ['Yes']
parceiro_yes = parceiro['parceiro'].isin(yes)

# %%
parceiro_yes = parceiro[parceiro_yes]

# %%
no = ['No']
parceiro_not = parceiro['parceiro'].isin(no)

# %%
parceiro_not = parceiro[parceiro_not]

# %%
len(parceiro_not) + len(parceiro_yes)
# Out:
# 7267

# %%
print(f'Cliente tem parceiro: {len(parceiro_yes)}\nCliente não tem parceiro: {len(parceiro_not)}\n')
# Out:
# Cliente tem parceiro: 3518
# Cliente não tem parceiro: 3749

# %% [markdown]
# # Acrescentando colunas e excluindo colunas

# %%
churn_de_clientes['genero'] = genero

# %%
churn_de_clientes['idade >= 65'] = idoso

# %%
churn_de_clientes['tem parceiro'] = parceiro

# %%
churn_de_clientes
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
churn_de_clientes = pd.DataFrame(churn_de_clientes[['customerID', 'Churn', 'genero', 'idade >= 65', 'tem parceiro', 'phone','internet', 'account']])

# %%
churn_de_clientes
# Out:
#       customerID Churn  genero  idade >= 65 tem parceiro  \
# 0     0002-ORFBO    No  Female            0          Yes
# 1     0003-MKNFE    No    Male            0           No
# 2     0004-TLHLJ   Yes    Male            0           No
# 3     0011-IGKFF   Yes    Male            1          Yes
# 4     0013-EXCHZ   Yes  Female            1          Yes
# ...          ...   ...     ...          ...          ...
# 7262  9987-LUTYD    No  Female            0           No
# 7263  9992-RRAMN   Yes    Male            0          Yes
# 7264  9992-UJOEL    No    Male            0           No
# 7265  9993-LHIEB    No    Male            0          Yes
# 7266  9995-HOTOH    No    Male            0          Yes
#
#                                                   phone  \
# 0        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1       {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2        {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# ...

# %% [markdown]
# # DataFrame dados pessoais do cliente

# %%
dados_pessoais = pd.DataFrame(churn_de_clientes[['genero', 'idade >= 65', 'tem parceiro', 'customerID']])

# %%
dados_pessoais = dados_pessoais.rename(columns={'customerID':'cliente_ID'})

# %%
dados_pessoais
# Out:
#       genero  idade >= 65 tem parceiro  cliente_ID
# 0     Female            0          Yes  0002-ORFBO
# 1       Male            0           No  0003-MKNFE
# 2       Male            0           No  0004-TLHLJ
# 3       Male            1          Yes  0011-IGKFF
# 4     Female            1          Yes  0013-EXCHZ
# ...      ...          ...          ...         ...
# 7262  Female            0           No  9987-LUTYD
# 7263    Male            0          Yes  9992-RRAMN
# 7264    Male            0           No  9992-UJOEL
# 7265    Male            0          Yes  9993-LHIEB
# 7266    Male            0          Yes  9995-HOTOH
#
# [7267 rows x 4 columns]

# %%
dados_pessoais.to_csv('dados_pessoais.csv', index=False)

# %% [markdown]
# # Phone

# %%
churn_de_clientes.head(5)
# Out:
#    customerID Churn  genero  idade >= 65 tem parceiro  \
# 0  0002-ORFBO    No  Female            0          Yes
# 1  0003-MKNFE    No    Male            0           No
# 2  0004-TLHLJ   Yes    Male            0           No
# 3  0011-IGKFF   Yes    Male            1          Yes
# 4  0013-EXCHZ   Yes  Female            1          Yes
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
# ...

# %%
selecao_phone = churn_de_clientes['phone']

# %%
selecao_phone.head(5)
# Out:
# 0     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1    {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# Name: phone, dtype: object

# %% [markdown]
# ## Assinatura de serviço telefônico com uma linha

# %%
servico_telefone = [p['PhoneService'] for p in selecao_phone]

# %%
servico_telefone = pd.DataFrame(servico_telefone, columns = ['servico_telefone'])

# %%
servico_telefone
# Out:
#      servico_telefone
# 0                 Yes
# 1                 Yes
# 2                 Yes
# 3                 Yes
# 4                 Yes
# ...               ...
# 7262              Yes
# 7263              Yes
# 7264              Yes
# 7265              Yes
# 7266               No
#
# [7267 rows x 1 columns]

# %%
yes = ['Yes']
servico_telefone_yes = servico_telefone['servico_telefone'].isin(yes)

# %%
servico_telefone_yes =  servico_telefone[servico_telefone_yes]

# %%
len(servico_telefone_yes)
# Out:
# 6560

# %%
no = ['No']
servico_telefone_not = servico_telefone['servico_telefone'].isin(no)

# %%
servico_telefone_not = servico_telefone[servico_telefone_not]

# %%
servico_telefone_not
# Out:
#      servico_telefone
# 10                 No
# 14                 No
# 16                 No
# 19                 No
# 25                 No
# ...               ...
# 7200               No
# 7201               No
# 7218               No
# 7238               No
# 7266               No
#
# [707 rows x 1 columns]

# %%
len(servico_telefone_yes) + len(servico_telefone_not)
# Out:
# 7267

# %%
print(f'Assinatura de serviço telefônico com uma linha\n  Sim: {len(servico_telefone_yes)}\n  Não: {len(servico_telefone_not)}')
# Out:
# Assinatura de serviço telefônico com uma linha
#   Sim: 6560
#   Não: 707

# %% [markdown]
# ## Assinatura de serviço telefônico com mais de uma linha

# %%
selecao_multiplas_linhas = [p['MultipleLines'] for p in selecao_phone]

# %%
multiplas_linhas = pd.DataFrame(selecao_multiplas_linhas, columns = ['servico_telefone_multiplas_linhas'])

# %%
multiplas_linhas
# Out:
#      servico_telefone_multiplas_linhas
# 0                                   No
# 1                                  Yes
# 2                                   No
# 3                                   No
# 4                                   No
# ...                                ...
# 7262                                No
# 7263                               Yes
# 7264                                No
# 7265                                No
# 7266                  No phone service
#
# [7267 rows x 1 columns]

# %%
yes = ['Yes']
multiplas_linhas_yes = multiplas_linhas['servico_telefone_multiplas_linhas'].isin(yes)

# %%
multiplas_linhas_yes = multiplas_linhas[multiplas_linhas_yes]

# %%
multiplas_linhas_yes
# Out:
#      servico_telefone_multiplas_linhas
# 1                                  Yes
# 7                                  Yes
# 9                                  Yes
# 11                                 Yes
# 13                                 Yes
# ...                                ...
# 7245                               Yes
# 7246                               Yes
# 7249                               Yes
# 7251                               Yes
# 7263                               Yes
#
# [3065 rows x 1 columns]

# %%
no = ['No']
multiplas_linhas_not = multiplas_linhas['servico_telefone_multiplas_linhas'].isin(no)

# %%
multiplas_linhas_not = multiplas_linhas[multiplas_linhas_not]

# %%
multiplas_linhas_not
# Out:
#      servico_telefone_multiplas_linhas
# 0                                   No
# 2                                   No
# 3                                   No
# 4                                   No
# 5                                   No
# ...                                ...
# 7260                                No
# 7261                                No
# 7262                                No
# 7264                                No
# 7265                                No
#
# [3495 rows x 1 columns]

# %%
len(multiplas_linhas_yes) + len(multiplas_linhas_not)
# Out:
# 6560

# %%
multiplas_linhas[multiplas_linhas['servico_telefone_multiplas_linhas'].isnull()].shape[0]
# Out:
# 0

# %%
multiplas_linhas_vazio['servico_telefone_multiplas_linhas'].drop_duplicates()
# Out:
# 0                   No
# 1                  Yes
# 10    No phone service
# Name: servico_telefone_multiplas_linhas, dtype: object

# %%
selecao_diferente = ((multiplas_linhas_vazio['servico_telefone_multiplas_linhas'] != 'Yes') & (multiplas_linhas_vazio['servico_telefone_multiplas_linhas'] != 'No'))

# %%
selecao_diferente
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7262    False
# 7263    False
# 7264    False
# 7265    False
# 7266     True
# Name: servico_telefone_multiplas_linhas, Length: 7267, dtype: bool

# %%
multiplas_linhas_diferente = multiplas_linhas[selecao_diferente]

# %%
multiplas_linhas_diferente
# Out:
#      servico_telefone_multiplas_linhas
# 10                    No phone service
# 14                    No phone service
# 16                    No phone service
# 19                    No phone service
# 25                    No phone service
# ...                                ...
# 7200                  No phone service
# 7201                  No phone service
# 7218                  No phone service
# 7238                  No phone service
# 7266                  No phone service
#
# [707 rows x 1 columns]

# %%
print(f'Assisnatura de mais de uma linha de telefone:\n  Sim: {len(multiplas_linhas_yes)}\n  Não: {len(multiplas_linhas_not)}\n  Sem serviço de telefone: {len(multiplas_linhas_diferente)}')
# Out:
# Assisnatura de mais de uma linha de telefone:
#   Sim: 3065
#   Não: 3495
#   Sem serviço de telefone: 707

# %% [markdown]
# ## Acrescentando coluna servico_telefone no DataFrame

# %%
churn_de_clientes['servico_telefone'] = servico_telefone

# %%
churn_de_clientes.head(5)
# Out:
#    customerID Churn  genero  idade >= 65 tem parceiro  \
# 0  0002-ORFBO    No  Female            0          Yes
# 1  0003-MKNFE    No    Male            0           No
# 2  0004-TLHLJ   Yes    Male            0           No
# 3  0011-IGKFF   Yes    Male            1          Yes
# 4  0013-EXCHZ   Yes  Female            1          Yes
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
# ...

# %% [markdown]
# ## Acrescentando coluna servico_telefone_multiplas_linhas no DataFrame

# %%
churn_de_clientes['servico_telefone_multiplas_linhas'] = multiplas_linhas

# %%
churn_de_clientes.head(5)
# Out:
#    customerID Churn  genero  idade >= 65 tem parceiro  \
# 0  0002-ORFBO    No  Female            0          Yes
# 1  0003-MKNFE    No    Male            0           No
# 2  0004-TLHLJ   Yes    Male            0           No
# 3  0011-IGKFF   Yes    Male            1          Yes
# 4  0013-EXCHZ   Yes  Female            1          Yes
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
# ...

# %% [markdown]
# ## DataFrame dados_telefonicos

# %%
dados_telefonicos = pd.DataFrame(churn_de_clientes[['servico_telefone', 'servico_telefone_multiplas_linhas']])

# %%
dados_telefonicos.head(5)
# Out:
#   servico_telefone servico_telefone_multiplas_linhas
# 0              Yes                                No
# 1              Yes                               Yes
# 2              Yes                                No
# 3              Yes                                No
# 4              Yes                                No

# %%
dados_telefonicos.to_csv('dados_telefonicos.csv', index=False)

# %% [markdown]
# ## Atualização do DataFrame churn_de_clientes

# %%
churn_de_clientes.head(5)
# Out:
#    customerID Churn  genero  idade >= 65 tem parceiro  \
# 0  0002-ORFBO    No  Female            0          Yes
# 1  0003-MKNFE    No    Male            0           No
# 2  0004-TLHLJ   Yes    Male            0           No
# 3  0011-IGKFF   Yes    Male            1          Yes
# 4  0013-EXCHZ   Yes  Female            1          Yes
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
# ...

# %%
churn_de_clientes = pd.DataFrame(churn_de_clientes[['customerID', 'Churn', 'genero', 'idade >= 65', 'tem parceiro', 'servico_telefone','servico_telefone_multiplas_linhas','internet', 'account']])

# %%
churn_de_clientes.head(5)
# Out:
#    customerID Churn  genero  idade >= 65 tem parceiro servico_telefone  \
# 0  0002-ORFBO    No  Female            0          Yes              Yes
# 1  0003-MKNFE    No    Male            0           No              Yes
# 2  0004-TLHLJ   Yes    Male            0           No              Yes
# 3  0011-IGKFF   Yes    Male            1          Yes              Yes
# 4  0013-EXCHZ   Yes  Female            1          Yes              Yes
#
#   servico_telefone_multiplas_linhas  \
# 0                                No
# 1                               Yes
# 2                                No
# 3                                No
# 4                                No
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %% [markdown]
# # Internet

# %% [markdown]
# ## Assinatura de um provedor internet

# %%
churn_de_clientes.head(5)
# Out:
#    customerID Churn  genero  idade >= 65 tem parceiro servico_telefone  \
# 0  0002-ORFBO    No  Female            0          Yes              Yes
# 1  0003-MKNFE    No    Male            0           No              Yes
# 2  0004-TLHLJ   Yes    Male            0           No              Yes
# 3  0011-IGKFF   Yes    Male            1          Yes              Yes
# 4  0013-EXCHZ   Yes  Female            1          Yes              Yes
#
#   servico_telefone_multiplas_linhas  \
# 0                                No
# 1                               Yes
# 2                                No
# 3                                No
# 4                                No
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
selecao_internet = churn_de_clientes['internet']

# %%
selecao_servico_provedor = [p['InternetService'] for p in selecao_internet]

# %%
servico_provedor = pd.DataFrame(selecao_servico_provedor, columns = ['assinatura_provedor_internet'])

# %%
servico_provedor.head(5)
# Out:
#   assinatura_provedor_internet
# 0                          DSL
# 1                          DSL
# 2                  Fiber optic
# 3                  Fiber optic
# 4                  Fiber optic

# %%
servico_provedor.drop_duplicates()
# Out:
#    assinatura_provedor_internet
# 0                           DSL
# 2                   Fiber optic
# 20                           No

# %%
dsl = ['DSL']
servico_provedor_DSL = servico_provedor['assinatura_provedor_internet'].isin(dsl)

# %%
servico_provedor_DSL = servico_provedor[servico_provedor_DSL]

# %%
servico_provedor_DSL
# Out:
#      assinatura_provedor_internet
# 0                             DSL
# 1                             DSL
# 5                             DSL
# 8                             DSL
# 9                             DSL
# ...                           ...
# 7253                          DSL
# 7262                          DSL
# 7264                          DSL
# 7265                          DSL
# 7266                          DSL
#
# [2488 rows x 1 columns]

# %%
fiber_optic = ['Fiber optic']
servico_provedor_fiber_optic = servico_provedor['assinatura_provedor_internet'].isin(fiber_optic)

# %%
servico_provedor_fiber_optic = servico_provedor[servico_provedor_fiber_optic]

# %%
servico_provedor_fiber_optic
# Out:
#      assinatura_provedor_internet
# 2                     Fiber optic
# 3                     Fiber optic
# 4                     Fiber optic
# 6                     Fiber optic
# 7                     Fiber optic
# ...                           ...
# 7255                  Fiber optic
# 7258                  Fiber optic
# 7259                  Fiber optic
# 7260                  Fiber optic
# 7263                  Fiber optic
#
# [3198 rows x 1 columns]

# %%
no = ['No']
servico_provedor_not = servico_provedor['assinatura_provedor_internet'].isin(no)

# %%
servico_provedor_not = servico_provedor[servico_provedor_not]

# %%
servico_provedor_not
# Out:
#      assinatura_provedor_internet
# 20                             No
# 23                             No
# 24                             No
# 27                             No
# 28                             No
# ...                           ...
# 7250                           No
# 7252                           No
# 7256                           No
# 7257                           No
# 7261                           No
#
# [1581 rows x 1 columns]

# %%
print(f'Assinatura de um provedor internet:\n  DSL:{len(servico_provedor_DSL)}\n  Fibra óptica: {len(servico_provedor_fiber_optic)}\n  Sem Provedor: {len(servico_provedor_not)}\nTotal: {len(servico_provedor)}')
# Out:
# Assinatura de um provedor internet:
#   DSL:2488
#   Fibra óptica: 3198
#   Sem Provedor: 1581
# Total: 7267

# %% [markdown]
# ## Assinatura adicional de segurança online

# %%
churn_de_clientes.head(5)
# Out:
#    customerID Churn  genero  idade >= 65 tem parceiro servico_telefone  \
# 0  0002-ORFBO    No  Female            0          Yes              Yes
# 1  0003-MKNFE    No    Male            0           No              Yes
# 2  0004-TLHLJ   Yes    Male            0           No              Yes
# 3  0011-IGKFF   Yes    Male            1          Yes              Yes
# 4  0013-EXCHZ   Yes  Female            1          Yes              Yes
#
#   servico_telefone_multiplas_linhas  \
# 0                                No
# 1                               Yes
# 2                                No
# 3                                No
# 4                                No
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
selecao_internet
# Out:
# 0       {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1       {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2       {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3       {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4       {'InternetService': 'Fiber optic', 'OnlineSecu...
#                               ...
# 7262    {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7263    {'InternetService': 'Fiber optic', 'OnlineSecu...
# 7264    {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7265    {'InternetService': 'DSL', 'OnlineSecurity': '...
# 7266    {'InternetService': 'DSL', 'OnlineSecurity': '...
# Name: internet, Length: 7267, dtype: object

# %%
selecao_seguranca_online = [p['OnlineSecurity'] for p in selecao_internet]

# %%
seguranca_online = pd.DataFrame(selecao_seguranca_online, columns = ['assinatura_adicional_seguranca_online'])

# %%
seguranca_online.head(5)
# Out:
#   assinatura_adicional_seguranca_online
# 0                                    No
# 1                                    No
# 2                                    No
# 3                                    No
# 4                                    No

# %%
seguranca_online.drop_duplicates()
# Out:
#    assinatura_adicional_seguranca_online
# 0                                     No
# 6                                    Yes
# 20                   No internet service

# %%
no = ['No']
seguranca_online_not = seguranca_online['assinatura_adicional_seguranca_online'].isin(no)

# %%
seguranca_online_not = seguranca_online[seguranca_online_not]

# %%
seguranca_online_not
# Out:
#      assinatura_adicional_seguranca_online
# 0                                       No
# 1                                       No
# 2                                       No
# 3                                       No
# 4                                       No
# ...                                    ...
# 7258                                    No
# 7259                                    No
# 7260                                    No
# 7263                                    No
# 7264                                    No
#
# [3608 rows x 1 columns]

# %%
yes = ['Yes']
seguranca_online_yes = seguranca_online['assinatura_adicional_seguranca_online'].isin(yes)

# %%
seguranca_online_yes = seguranca_online[seguranca_online_yes]

# %%
seguranca_online_yes
# Out:
#      assinatura_adicional_seguranca_online
# 6                                      Yes
# 7                                      Yes
# 8                                      Yes
# 9                                      Yes
# 10                                     Yes
# ...                                    ...
# 7242                                   Yes
# 7249                                   Yes
# 7262                                   Yes
# 7265                                   Yes
# 7266                                   Yes
#
# [2078 rows x 1 columns]

# %%
no_service = ['No internet service']
seguranca_online_no_service = seguranca_online['assinatura_adicional_seguranca_online'].isin(no_service)

# %%
seguranca_online_no_service = seguranca_online[seguranca_online_no_service]

# %%
seguranca_online_no_service
# Out:
#      assinatura_adicional_seguranca_online
# 20                     No internet service
# 23                     No internet service
# 24                     No internet service
# 27                     No internet service
# 28                     No internet service
# ...                                    ...
# 7250                   No internet service
# 7252                   No internet service
# 7256                   No internet service
# 7257                   No internet service
# 7261                   No internet service
#
# [1581 rows x 1 columns]

# %%
print(f'Assinatura adicional de segurança online:\n  Sim: {len(seguranca_online_yes)}\n  Não: {len(seguranca_online_not)}\n  Sem serviço de internet: {len(seguranca_online_no_service)}\nTotal: {len(seguranca_online)}')
# Out:
# Assinatura adicional de segurança online:
#   Sim: 2078
#   Não: 3608
#   Sem serviço de internet: 1581
# Total: 7267

# %% [markdown]
# ## Acrescentando coluna assinatura_provedor_internet

# %%
churn_de_clientes['assinatura_provedor_internet'] = servico_internet

# %%
churn_de_clientes.head(5)
# Out:
#    customerID Churn  genero  idade >= 65 tem parceiro servico_telefone  \
# 0  0002-ORFBO    No  Female            0          Yes              Yes
# 1  0003-MKNFE    No    Male            0           No              Yes
# 2  0004-TLHLJ   Yes    Male            0           No              Yes
# 3  0011-IGKFF   Yes    Male            1          Yes              Yes
# 4  0013-EXCHZ   Yes  Female            1          Yes              Yes
#
#   servico_telefone_multiplas_linhas  \
# 0                                No
# 1                               Yes
# 2                                No
# 3                                No
# 4                                No
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %% [markdown]
# ## Acrescentando coluna assinatura_adicional_seguranca_online

# %%
churn_de_clientes['assinatura_adicional_seguranca_online'] = seguranca_online

# %%
churn_de_clientes.head(5)
# Out:
#    customerID Churn  genero  idade >= 65 tem parceiro servico_telefone  \
# 0  0002-ORFBO    No  Female            0          Yes              Yes
# 1  0003-MKNFE    No    Male            0           No              Yes
# 2  0004-TLHLJ   Yes    Male            0           No              Yes
# 3  0011-IGKFF   Yes    Male            1          Yes              Yes
# 4  0013-EXCHZ   Yes  Female            1          Yes              Yes
#
#   servico_telefone_multiplas_linhas  \
# 0                                No
# 1                               Yes
# 2                                No
# 3                                No
# 4                                No
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %% [markdown]
# ## DataFrame servicos_internet

# %%
servicos_internet = pd.DataFrame(churn_de_clientes[['assinatura_provedor_internet', 'assinatura_adicional_seguranca_online']])

# %%
servicos_internet.head(5)
# Out:
#   assinatura_provedor_internet assinatura_adicional_seguranca_online
# 0                          DSL                                    No
# 1                          DSL                                    No
# 2                  Fiber optic                                    No
# 3                  Fiber optic                                    No
# 4                  Fiber optic                                    No

# %%
servicos_internet.to_csv('servicos_internet.csv', index=False)

# %% [markdown]
# ## Atualização DataFrame churn_de_clientes

# %%
churn_de_clientes = pd.DataFrame(churn_de_clientes[['customerID', 'Churn', 'genero', 'idade >= 65', 'tem parceiro', 'servico_telefone','servico_telefone_multiplas_linhas','assinatura_provedor_internet', 'assinatura_adicional_seguranca_online', 'account']])

# %%
churn_de_clientes.head(5)
# Out:
#    customerID Churn  genero  idade >= 65 tem parceiro servico_telefone  \
# 0  0002-ORFBO    No  Female            0          Yes              Yes
# 1  0003-MKNFE    No    Male            0           No              Yes
# 2  0004-TLHLJ   Yes    Male            0           No              Yes
# 3  0011-IGKFF   Yes    Male            1          Yes              Yes
# 4  0013-EXCHZ   Yes  Female            1          Yes              Yes
#
#   servico_telefone_multiplas_linhas assinatura_provedor_internet  \
# 0                                No                          DSL
# 1                               Yes                          DSL
# 2                                No                  Fiber optic
# 3                                No                  Fiber optic
# 4                                No                  Fiber optic
#
#   assinatura_adicional_seguranca_online  \
# 0                                    No
# 1                                    No
# ...
