# %%
import pandas as pd
import numpy as np

# %%
data_frame = pd.read_json('https://raw.githubusercontent.com/sthemonica/alura-voz/main/Dados/Telco-Customer-Churn.json')

# %%
data_frame.head(10)
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 5  0013-MHZWF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 6  0013-SMEOE    No  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 7  0014-BMAQU    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 8  0015-UOCOJ    No  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 9  0016-QLJIS    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# ...

# %%
len(data_frame)
# Out:
# 7267

# %%
type(data_frame)
# Out:
# pandas.core.frame.DataFrame

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
data_frame.dtypes
# Out:
# customerID    object
# Churn         object
# customer      object
# phone         object
# internet      object
# account       object
# dtype: object

# %%
tipos_de_dados = pd.DataFrame(data_frame.dtypes, columns = ['Tipos de Dados'])

# %%
tipos_de_dados.columns.name = 'Variáveis'

# %%
tipos_de_dados
# Out:
# Variáveis  Tipos de Dados
# customerID         object
# Churn              object
# customer           object
# phone              object
# internet           object
# account            object

# %%
data_frame.shape
# Out:
# (7267, 6)

# %%
print(f'Número de Variáveis: {data_frame.shape[1]} \nNúmero de IDs cadastrados: {data_frame.shape[0]}')
# Out:
# Número de Variáveis: 6
# Número de IDs cadastrados: 7267

# %%
data_frame.head(5)
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
yes = ['Yes']
selecao_yes = data_frame['Churn'].isin(yes)
churn_yes = data_frame[selecao_yes]

# %%
churn_yes.head(5)
# Out:
#     customerID Churn                                           customer  \
# 2   0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3   0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4   0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 18  0022-TCJCI   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 19  0023-HGHWL   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
#
#                                                 phone  \
# 2      {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3      {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4      {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 18     {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 19  {'PhoneService': 'No', 'MultipleLines': 'No ph...
#
#                                              internet  \
# 2   {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3   {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
no = ['No']
selecao_no = data_frame['Churn'].isin(no)
churn_no = data_frame[selecao_no]

# %%
churn_no.head(5)
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 5  0013-MHZWF    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 6  0013-SMEOE    No  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 7  0014-BMAQU    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 5   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 6   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 7  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 5  {'InternetService': 'DSL', 'OnlineSecurity': '...
# ...

# %%
data_frame['Churn'].drop_duplicates()
# Out:
# 0      No
# 2     Yes
# 30
# Name: Churn, dtype: object

# %%
vazio = ['']
selecao_vazio = data_frame['Churn'].isin(vazio)
churn_vazio = data_frame[selecao_vazio]

# %%
churn_vazio.head(5)
# Out:
#      customerID Churn                                           customer  \
# 30   0047-ZHDTW        {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 75   0120-YZLQA        {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 96   0154-QYHJU        {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 98   0162-RZGMZ        {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# 175  0274-VVQOQ        {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
#
#                                                phone  \
# 30   {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 75    {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 96    {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 98    {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 175  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
#
#                                               internet  \
# 30   {'InternetService': 'Fiber optic', 'OnlineSecu...
# 75   {'InternetService': 'No', 'OnlineSecurity': 'N...
# ...

# %%
soma_churn = len(churn_yes) + len(churn_no) + len(churn_vazio)

# %%
print(f'Total de clientes: {soma_churn}\nDesistência de clientes: {len(churn_yes)}\nPermanência de clientes: {len(churn_no)}\nCampo Vazio: {len(churn_vazio)}')
# Out:
# Total de clientes: 7267
# Desistência de clientes: 1869
# Permanência de clientes: 5174
# Campo Vazio: 224

# %% [markdown]
# # customer

# %%
customer = pd.read_csv('dados_pessoais.csv')

# %%
customer.head(5)
# Out:
#    cliente_ID desistencia  genero  idade_>=_65 tem_parceiro tem_dependentes
# 0  0002-ORFBO          No  Female            0          Yes             Yes
# 1  0003-MKNFE          No    Male            0           No              No
# 2  0004-TLHLJ         Yes    Male            0           No              No
# 3  0011-IGKFF         Yes    Male            1          Yes              No
# 4  0013-EXCHZ         Yes  Female            1          Yes              No

# %%
customer = customer.rename(columns = {'Churn': 'desistencia'})

# %%
customer.head(5)
# Out:
#    cliente_ID desistencia  genero  idade_>=_65 tem_parceiro tem_dependentes
# 0  0002-ORFBO          No  Female            0          Yes             Yes
# 1  0003-MKNFE          No    Male            0           No              No
# 2  0004-TLHLJ         Yes    Male            0           No              No
# 3  0011-IGKFF         Yes    Male            1          Yes              No
# 4  0013-EXCHZ         Yes  Female            1          Yes              No

# %%
customer.to_csv('dados_pessoais.csv', index=False)

# %% [markdown]
# #####################################################
# INFORMAÇÕES PESSOAIS DO CLIENTE:
# #####################################################
#
#
# Sexo Masculino: 3675
#
# Sexo Feminino: 3592
#
# Total: 7267
#
# --------------------------------------------------
#
#
# Idade >= 65: 1182
#
# Idade < 65: 6085
#
# Total: 7267
#
# --------------------------------------------------
#
#
# Cliente tem parceiro: 3518
#
# Cliente não tem parceiro: 3749
#
# Total: 7267
#
# --------------------------------------------------
#
#
# Cliente tem dependentes: 2181
#
# Cliente não tem parceiro: 5086
#
# Total: 7267
#
# #####################################################
# DESISTÊNCIA DO CLIENTE:
# #####################################################
#
# Desistência de clientes: 1869
#
# Permanência de clientes: 5174
#
# Campo Vazio: 224
#
# Total de clientes: 7267

# %% [markdown]
# # phone

# %%
phone = pd.read_csv('dados_telefonicos.csv')

# %%
phone.head(5)
# Out:
#    cliente_ID servico_telefone servico_telefone_multiplas_linhas
# 0  0002-ORFBO              Yes                                No
# 1  0003-MKNFE              Yes                               Yes
# 2  0004-TLHLJ              Yes                                No
# 3  0011-IGKFF              Yes                                No
# 4  0013-EXCHZ              Yes                                No

# %% [markdown]
# ##################################################
#             INFORMAÇÕES TELEFONE
# ##################################################
#
# Assinatura de serviço telefônico com uma linha
#
#   Sim: 6560
#
#   Não: 707
#
# Total: 7267
#
# --------------------------------------------------
#
# Assisnatura de mais de uma linha de telefone:
#
#   Sim: 3065
#
#   Não: 3495
#
#   Sem serviço de telefone: 707
#
# Total: 7267

# %% [markdown]
# # internet

# %%
internet = pd.read_csv('servicos_internet.csv')

# %%
internet.head(5)
# Out:
#    cliente_ID assinatura_provedor_internet  \
# 0  0002-ORFBO                          DSL
# 1  0003-MKNFE                          DSL
# 2  0004-TLHLJ                  Fiber optic
# 3  0011-IGKFF                  Fiber optic
# 4  0013-EXCHZ                  Fiber optic
#
#   assinatura_adicional_seguranca_online assinatura_adicional_backup_online  \
# 0                                    No                                Yes
# 1                                    No                                 No
# 2                                    No                                 No
# 3                                    No                                Yes
# 4                                    No                                 No
#
#   assinatura_adicional_protecao_dispositivo  \
# 0                                        No
# 1                                        No
# 2                                       Yes
# 3                                       Yes
# ...

# %% [markdown]
# ##################################################
# INFORMAÇÕES SOBRE INTERNET
# ##################################################
#
# Assinatura de um provedor internet:
#
#   DSL:2488
#
#   Fibra óptica: 3198
#
#   Sem Provedor: 1581
#
# Total: 7267
#
# --------------------------------------------------
#
# Assinatura adicional de segurança online:
#
#   Sim: 2078
#
#   Não: 3608
#
#   Sem serviço de internet: 1581
#
# Total: 7267
#
# --------------------------------------------------
#
# Assinatura adicional de backup online:
#
#   Sim: 2504
#
#   Não: 3182
#
#   Sem serviço de internet: 1581
#
# Total: 7267
#
# --------------------------------------------------
#
# Assinatura adicional de proteção no dispositivo:
#
#   Sim: 2491
#
#   Não: 3195
#
#   Sem serviço de internet: 1581
#
# Total: 7267
#
# --------------------------------------------------
#
# Assinatura adicional de suporte técnico, menos tempo de espera:
#
#   Sim: 2104
#
#   Não: 3582
#
#   Sem serviço de internet: 1581
#
# Total: 7267
#
# --------------------------------------------------
#
# Assinatura adicional de TV a cabo:
#
#   Sim: 2790
#
#   Não: 2896
#
#   Sem serviço de internet: 1581
#
# Total: 7267
#
# --------------------------------------------------
#
# Assinatura adicional de streaming de filmes:
#
#   Sim: 2816
#
#   Não: 2870
#
#   Sem serviço de internet: 1581
#
# Total: 7267

# %% [markdown]
# # account

# %%
account = pd.read_csv('conta.csv')

# %%
account.head(5)
# Out:
#    cliente_ID        contrato fatura_online   forma_pagamento  gastos_mensais  \
# 0  0002-ORFBO        One year           Yes      Mailed check            65.6
# 1  0003-MKNFE  Month-to-month            No      Mailed check            59.9
# 2  0004-TLHLJ  Month-to-month           Yes  Electronic check            73.9
# 3  0011-IGKFF  Month-to-month           Yes  Electronic check            98.0
# 4  0013-EXCHZ  Month-to-month           Yes      Mailed check            83.9
#
#   gasto_total
# 0       593.3
# 1       542.4
# 2      280.85
# 3     1237.85
# 4       267.4

# %% [markdown]
# ##################################################
# INFORMAÇÕES SOBRE CONTA
# ##################################################
#
# Contratos:
#
#   Contrato de 1 Ano: 1519
#
#   Contrato de 2 Anos: 1743
#
#   Contrato de Mês a Mês: 4005
#
# Total: 7267
#
# --------------------------------------------------
#
# Receber fatura online:
#
#   Sim: 4311
#
#   Não: 2956
#
# Total: 7267
#
# --------------------------------------------------
#
# Forma de Pagamento:
#
#   Cheque Enviado: 1665
#
#   Cheque Eletrônico: 2445
#
#   Cartão de Crédito(automático): 1568
#
#   Transferência Bancaria(automático): 1589
#
# Total: 7267

# %%
dados = pd.read_csv('churn_de_clientes.csv')

# %%
dados.head(5)
# Out:
#    cliente_ID Churn  genero  idade_>=_65 tem_parceiro tem_dependentes  \
# 0  0002-ORFBO    No  Female            0          Yes             Yes
# 1  0003-MKNFE    No    Male            0           No              No
# 2  0004-TLHLJ   Yes    Male            0           No              No
# 3  0011-IGKFF   Yes    Male            1          Yes              No
# 4  0013-EXCHZ   Yes  Female            1          Yes              No
#
#   assinatura_provedor_internet assinatura_adicional_seguranca_online  \
# 0                          DSL                                    No
# 1                          DSL                                    No
# 2                  Fiber optic                                    No
# 3                  Fiber optic                                    No
# 4                  Fiber optic                                    No
#
#   assinatura_adicional_backup_online  \
# 0                                Yes
# 1                                 No
# ...

# %%
dados = dados.rename(columns = {'Churn': 'desistencia'})

# %%
dados.head(5)
# Out:
#    cliente_ID desistencia  genero  idade_>=_65 tem_parceiro tem_dependentes  \
# 0  0002-ORFBO          No  Female            0          Yes             Yes
# 1  0003-MKNFE          No    Male            0           No              No
# 2  0004-TLHLJ         Yes    Male            0           No              No
# 3  0011-IGKFF         Yes    Male            1          Yes              No
# 4  0013-EXCHZ         Yes  Female            1          Yes              No
#
#   assinatura_provedor_internet assinatura_adicional_seguranca_online  \
# 0                          DSL                                    No
# 1                          DSL                                    No
# 2                  Fiber optic                                    No
# 3                  Fiber optic                                    No
# 4                  Fiber optic                                    No
#
#   assinatura_adicional_backup_online  \
# 0                                Yes
# ...

# %%
dados.isnull()
# Out:
#       cliente_ID  desistencia  genero  idade_>=_65  tem_parceiro  \
# 0          False        False   False        False         False
# 1          False        False   False        False         False
# 2          False        False   False        False         False
# 3          False        False   False        False         False
# 4          False        False   False        False         False
# ...          ...          ...     ...          ...           ...
# 7262       False        False   False        False         False
# 7263       False        False   False        False         False
# 7264       False        False   False        False         False
# 7265       False        False   False        False         False
# 7266       False        False   False        False         False
#
#       tem_dependentes  assinatura_provedor_internet  \
# 0               False                         False
# 1               False                         False
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 18 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   cliente_ID                                               7267 non-null   object
#  1   desistencia                                              7043 non-null   object
#  2   genero                                                   7267 non-null   object
#  3   idade_>=_65                                              7267 non-null   int64
#  4   tem_parceiro                                             7267 non-null   object
#  5   tem_dependentes                                          7267 non-null   object
#  6   assinatura_provedor_internet                             7267 non-null   object
#  7   assinatura_adicional_seguranca_online                    7267 non-null   object
# ...

# %%
no_service = ['No internet service']

# %%
selecao = dados['assinatura_adicional_seguranca_online'].isin(no_service)

# %%
no_service = dados[selecao]

# %%
no_service
# Out:
#       cliente_ID desistencia  genero  idade_>=_65 tem_parceiro  \
# 20    0023-UYUPN          No  Female            1          Yes
# 23    0030-FNXPP          No  Female            0           No
# 24    0031-PVLZI         Yes  Female            0          Yes
# 27    0040-HALCW          No    Male            0          Yes
# 28    0042-JVWOJ          No    Male            0           No
# ...          ...         ...     ...          ...          ...
# 7250  9970-QBCDA          No  Female            0           No
# 7252  9972-EWRJS          No  Female            0          Yes
# 7256  9975-GPKZU          No    Male            0          Yes
# 7257  9975-SKRNR          No    Male            0           No
# 7261  9986-BONCE         Yes  Female            0           No
#
#      tem_dependentes assinatura_provedor_internet  \
# 20                No                           No
# 23                No                           No
# 24               Yes                           No
# ...

# %%
print(f'{len(no_service)} clientes não tem contrato de nenhum serviço e {len(desistencia_vazio)} tem a coluna desistencia vazia' )
# Out:
# 1581 clientes não tem contrato de nenhum serviço e 224 tem a coluna desistencia vazia

# %% [markdown]
# # eliminando colunas sem nenhum tipo de serviço ou com a coluna de desistência vazia

# %% [markdown]
# ## apagar linhas vazias da coluna desistencia

# %%
desistencia_vazio = dados[dados['desistencia'].isnull()]

# %%
desistencia_vazio
# Out:
#       cliente_ID desistencia  genero  idade_>=_65 tem_parceiro  \
# 30    0047-ZHDTW         NaN  Female            0           No
# 75    0120-YZLQA         NaN    Male            0           No
# 96    0154-QYHJU         NaN    Male            0           No
# 98    0162-RZGMZ         NaN  Female            1           No
# 175   0274-VVQOQ         NaN    Male            1          Yes
# ...          ...         ...     ...          ...          ...
# 7158  9840-GSRFX         NaN  Female            0           No
# 7180  9872-RZQQB         NaN  Female            0          Yes
# 7211  9920-GNDMB         NaN    Male            0           No
# 7239  9955-RVWSC         NaN  Female            0          Yes
# 7247  9966-VYRTZ         NaN  Female            0          Yes
#
#      tem_dependentes assinatura_provedor_internet  \
# 30                No                  Fiber optic
# 75                No                           No
# 96                No                          DSL
# ...

# %%
A = dados.shape[0]
dados.dropna(subset = ['desistencia'], inplace = True)
B = dados.shape[0]
A-B
# Out:
# 224

# %%
dados[dados['desistencia'].isnull()]
# Out:
# Empty DataFrame
# Columns: [cliente_ID, desistencia, genero, idade_>=_65, tem_parceiro, tem_dependentes, assinatura_provedor_internet, assinatura_adicional_seguranca_online, assinatura_adicional_backup_online, assinatura_adicional_protecao_dispositivo, assinatura_adicional_suporte_tecnico_menos_tempo_espera, assinatura_TV_cabo, assinatura_streaming_filmes, contrato, fatura_online, forma_pagamento, gastos_mensais, gasto_total]
# Index: []

# %%
len(dados)
# Out:
# 7043

# %%
selecao = dados['assinatura_adicional_seguranca_online'].isin(['No internet service'])

# %%
A = dados.shape[0]
dados = dados[~selecao]
B = dados.shape[0]
A - B
# Out:
# 1526

# %%
dados.head(30)
# Out:
#     cliente_ID desistencia  genero  idade_>=_65 tem_parceiro tem_dependentes  \
# 0   0002-ORFBO          No  Female            0          Yes             Yes
# 1   0003-MKNFE          No    Male            0           No              No
# 2   0004-TLHLJ         Yes    Male            0           No              No
# 3   0011-IGKFF         Yes    Male            1          Yes              No
# 4   0013-EXCHZ         Yes  Female            1          Yes              No
# 5   0013-MHZWF          No  Female            0           No             Yes
# 6   0013-SMEOE          No  Female            1          Yes              No
# 7   0014-BMAQU          No    Male            0          Yes              No
# 8   0015-UOCOJ          No  Female            1           No              No
# 9   0016-QLJIS          No  Female            0          Yes             Yes
# 10  0017-DINOC          No    Male            0           No              No
# ...

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5517 entries, 0 to 7266
# Data columns (total 18 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   cliente_ID                                               5517 non-null   object
#  1   desistencia                                              5517 non-null   object
#  2   genero                                                   5517 non-null   object
#  3   idade_>=_65                                              5517 non-null   int64
#  4   tem_parceiro                                             5517 non-null   object
#  5   tem_dependentes                                          5517 non-null   object
#  6   assinatura_provedor_internet                             5517 non-null   object
#  7   assinatura_adicional_seguranca_online                    5517 non-null   object
# ...

# %% [markdown]
# # Atualização das Informações

# %%
dados.dtypes
# Out:
# cliente_ID                                                  object
# desistencia                                                 object
# genero                                                      object
# idade_>=_65                                                  int64
# tem_parceiro                                                object
# tem_dependentes                                             object
# assinatura_provedor_internet                                object
# assinatura_adicional_seguranca_online                       object
# assinatura_adicional_backup_online                          object
# assinatura_adicional_protecao_dispositivo                   object
# assinatura_adicional_suporte_tecnico_menos_tempo_espera     object
# assinatura_TV_cabo                                          object
# assinatura_streaming_filmes                                 object
# contrato                                                    object
# ...

# %%
tipos_de_dados = pd.DataFrame(dados.dtypes, columns = ['Tipos de Dados'])
tipos_de_dados.columns.name = 'Variáveis'
tipos_de_dados
# Out:
# Variáveis                                          Tipos de Dados
# cliente_ID                                                 object
# desistencia                                                object
# genero                                                     object
# idade_>=_65                                                 int64
# tem_parceiro                                               object
# tem_dependentes                                            object
# assinatura_provedor_internet                               object
# assinatura_adicional_seguranca_online                      object
# assinatura_adicional_backup_online                         object
# assinatura_adicional_protecao_dispositivo                  object
# assinatura_adicional_suporte_tecnico_menos_temp...         object
# assinatura_TV_cabo                                         object
# assinatura_streaming_filmes                                object
# ...

# %%
print(f'A base de dados apresenta {dados.shape[0]} e {dados.shape[1]} variáveis')
# Out:
# A base de dados apresenta 5517 e 18 variáveis

# %% [markdown]
# # acrescentar coluna gastos_diarios

# %%
dados.head(5)
# Out:
#    cliente_ID desistencia  genero  idade_>=_65 tem_parceiro tem_dependentes  \
# 0  0002-ORFBO          No  Female            0          Yes             Yes
# 1  0003-MKNFE          No    Male            0           No              No
# 2  0004-TLHLJ         Yes    Male            0           No              No
# 3  0011-IGKFF         Yes    Male            1          Yes              No
# 4  0013-EXCHZ         Yes  Female            1          Yes              No
#
#   assinatura_provedor_internet assinatura_adicional_seguranca_online  \
# 0                          DSL                                    No
# 1                          DSL                                    No
# 2                  Fiber optic                                    No
# 3                  Fiber optic                                    No
# 4                  Fiber optic                                    No
#
#   assinatura_adicional_backup_online  \
# 0                                Yes
# ...

# %%
dados.insert(17,'gastos_diarios',((dados['gastos_mensais'] / 30).round(2)))

# %%
dados.head(5)
# Out:
#    cliente_ID desistencia  genero  idade_>=_65 tem_parceiro tem_dependentes  \
# 0  0002-ORFBO          No  Female            0          Yes             Yes
# 1  0003-MKNFE          No    Male            0           No              No
# 2  0004-TLHLJ         Yes    Male            0           No              No
# 3  0011-IGKFF         Yes    Male            1          Yes              No
# 4  0013-EXCHZ         Yes  Female            1          Yes              No
#
#   assinatura_provedor_internet assinatura_adicional_seguranca_online  \
# 0                          DSL                                    No
# 1                          DSL                                    No
# 2                  Fiber optic                                    No
# 3                  Fiber optic                                    No
# 4                  Fiber optic                                    No
#
#   assinatura_adicional_backup_online  \
# 0                                Yes
# ...

# %% [markdown]
# # Atualizar DataFrame

# %%
dados.to_csv('dataFrame.csv', index=False)
