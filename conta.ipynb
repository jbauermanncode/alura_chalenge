# %%
import pandas as pd

# %%
churn_de_clientes = pd.read_json('https://raw.githubusercontent.com/sthemonica/alura-voz/main/Dados/Telco-Customer-Churn.json')

# %%
churn_de_clientes.head(5)
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %%
conta = churn_de_clientes['account']

# %%
conta.head(5)
# Out:
# 0    {'Contract': 'One year', 'PaperlessBilling': '...
# 1    {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2    {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3    {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4    {'Contract': 'Month-to-month', 'PaperlessBilli...
# Name: account, dtype: object

# %%
conta[0]
# Out:
# {'Contract': 'One year',
#  'PaperlessBilling': 'Yes',
#  'PaymentMethod': 'Mailed check',
#  'Charges': {'Monthly': 65.6, 'Total': '593.3'}}

# %% [markdown]
# ## tipo de contrato

# %%
selecao = [i['Contract'] for i in conta]

# %%
contrato = pd.DataFrame(selecao, columns = ['contrato'])

# %%
contrato
# Out:
#             contrato
# 0           One year
# 1     Month-to-month
# 2     Month-to-month
# 3     Month-to-month
# 4     Month-to-month
# ...              ...
# 7262        One year
# 7263  Month-to-month
# 7264  Month-to-month
# 7265        Two year
# 7266        Two year
#
# [7267 rows x 1 columns]

# %%
contrato.drop_duplicates()
# Out:
#          contrato
# 0        One year
# 1  Month-to-month
# 6        Two year

# %%
one_year = ['One year']
contrato_one_year = contrato['contrato'].isin(one_year)
contrato_one_year = contrato[contrato_one_year]

# %%
contrato_one_year
# Out:
#       contrato
# 0     One year
# 16    One year
# 18    One year
# 20    One year
# 26    One year
# ...        ...
# 7249  One year
# 7254  One year
# 7258  One year
# 7259  One year
# 7262  One year
#
# [1519 rows x 1 columns]

# %%
two_year = ['Two year']
contrato_two_year = contrato['contrato'].isin(two_year)
contrato_two_year = contrato[contrato_two_year]

# %%
contrato_two_year
# Out:
#       contrato
# 6     Two year
# 7     Two year
# 9     Two year
# 10    Two year
# 11    Two year
# ...        ...
# 7245  Two year
# 7252  Two year
# 7256  Two year
# 7265  Two year
# 7266  Two year
#
# [1743 rows x 1 columns]

# %%
month = ['Month-to-month']
contrato_month = contrato['contrato'].isin(month)
contrato_month = contrato[contrato_month]

# %%
contrato_month
# Out:
#             contrato
# 1     Month-to-month
# 2     Month-to-month
# 3     Month-to-month
# 4     Month-to-month
# 5     Month-to-month
# ...              ...
# 7257  Month-to-month
# 7260  Month-to-month
# 7261  Month-to-month
# 7263  Month-to-month
# 7264  Month-to-month
#
# [4005 rows x 1 columns]

# %%
soma_contrato = len(contrato_one_year) + len(contrato_two_year) + len(contrato_month)

# %%
soma_contrato
# Out:
# 7267

# %%
conta[0]
# Out:
# {'Contract': 'One year',
#  'PaperlessBilling': 'Yes',
#  'PaymentMethod': 'Mailed check',
#  'Charges': {'Monthly': 65.6, 'Total': '593.3'}}

# %% [markdown]
# ##  se o cliente prefere receber online a fatura

# %%
selecao = [i['PaperlessBilling'] for i in conta]

# %%
fatura_online = pd.DataFrame(selecao, columns = ['fatura_online'])

# %%
fatura_online.head(5)
# Out:
#   fatura_online
# 0           Yes
# 1            No
# 2           Yes
# 3           Yes
# 4           Yes

# %%
fatura_online.drop_duplicates()
# Out:
#   fatura_online
# 0           Yes
# 1            No

# %%
fatura_online_yes = fatura_online['fatura_online'].isin(['Yes'])
fatura_online_yes = fatura_online[fatura_online_yes]

# %%
fatura_online_yes
# Out:
#      fatura_online
# 0              Yes
# 2              Yes
# 3              Yes
# 4              Yes
# 5              Yes
# ...            ...
# 7258           Yes
# 7259           Yes
# 7260           Yes
# 7263           Yes
# 7264           Yes
#
# [4311 rows x 1 columns]

# %%
fatura_online_not = fatura_online['fatura_online'].isin(['No'])
fatura_online_not = fatura_online[fatura_online_not]

# %%
fatura_online_not
# Out:
#      fatura_online
# 1               No
# 10              No
# 14              No
# 16              No
# 18              No
# ...            ...
# 7257            No
# 7261            No
# 7262            No
# 7265            No
# 7266            No
#
# [2956 rows x 1 columns]

# %%
soma_fatura = len(fatura_online_yes) + len(fatura_online_not)

# %%
soma_fatura
# Out:
# 7267

# %%
conta[0]
# Out:
# {'Contract': 'One year',
#  'PaperlessBilling': 'Yes',
#  'PaymentMethod': 'Mailed check',
#  'Charges': {'Monthly': 65.6, 'Total': '593.3'}}

# %% [markdown]
# ## forma de pagamento

# %%
selecao = [d['PaymentMethod'] for d in conta]

# %%
forma_pagamento = pd.DataFrame(selecao, columns = ['forma_pagamento'])

# %%
forma_pagamento.head(5)
# Out:
#     forma_pagamento
# 0      Mailed check
# 1      Mailed check
# 2  Electronic check
# 3  Electronic check
# 4      Mailed check

# %%
forma_pagamento.drop_duplicates()
# Out:
#              forma_pagamento
# 0               Mailed check
# 2           Electronic check
# 5    Credit card (automatic)
# 6  Bank transfer (automatic)

# %%
forma_pagamento_mailed = forma_pagamento['forma_pagamento'].isin(['Mailed check'])
forma_pagamento_mailed = forma_pagamento[forma_pagamento_mailed]

# %%
forma_pagamento_mailed
# Out:
#      forma_pagamento
# 0       Mailed check
# 1       Mailed check
# 4       Mailed check
# 9       Mailed check
# 16      Mailed check
# ...              ...
# 7259    Mailed check
# 7260    Mailed check
# 7262    Mailed check
# 7264    Mailed check
# 7265    Mailed check
#
# [1665 rows x 1 columns]

# %%
forma_pagamento_electronic = forma_pagamento['forma_pagamento'].isin(['Electronic check'])
forma_pagamento_electronic = forma_pagamento[forma_pagamento_electronic]

# %%
forma_pagamento_electronic
# Out:
#        forma_pagamento
# 2     Electronic check
# 3     Electronic check
# 8     Electronic check
# 12    Electronic check
# 17    Electronic check
# ...                ...
# 7246  Electronic check
# 7251  Electronic check
# 7254  Electronic check
# 7263  Electronic check
# 7266  Electronic check
#
# [2445 rows x 1 columns]

# %%
forma_pagamento_card = forma_pagamento['forma_pagamento'].isin(['Credit card (automatic)'])
forma_pagamento_card  = forma_pagamento[forma_pagamento_card]

# %%
forma_pagamento_card
# Out:
#               forma_pagamento
# 5     Credit card (automatic)
# 7     Credit card (automatic)
# 10    Credit card (automatic)
# 11    Credit card (automatic)
# 15    Credit card (automatic)
# ...                       ...
# 7241  Credit card (automatic)
# 7245  Credit card (automatic)
# 7250  Credit card (automatic)
# 7255  Credit card (automatic)
# 7256  Credit card (automatic)
#
# [1568 rows x 1 columns]

# %%
forma_pagamento_bank = forma_pagamento['forma_pagamento'].isin(['Bank transfer (automatic)'])
forma_pagamento_bank  = forma_pagamento[forma_pagamento_bank]

# %%
forma_pagamento_bank
# Out:
#                 forma_pagamento
# 6     Bank transfer (automatic)
# 13    Bank transfer (automatic)
# 14    Bank transfer (automatic)
# 25    Bank transfer (automatic)
# 26    Bank transfer (automatic)
# ...                         ...
# 7249  Bank transfer (automatic)
# 7252  Bank transfer (automatic)
# 7253  Bank transfer (automatic)
# 7258  Bank transfer (automatic)
# 7261  Bank transfer (automatic)
#
# [1589 rows x 1 columns]

# %%
soma_pagamento = len(forma_pagamento_mailed) + len(forma_pagamento_electronic) + len(forma_pagamento_card) + len(forma_pagamento_bank)

# %%
soma_pagamento
# Out:
# 7267

# %%
conta[0]
# Out:
# {'Contract': 'One year',
#  'PaperlessBilling': 'Yes',
#  'PaymentMethod': 'Mailed check',
#  'Charges': {'Monthly': 65.6, 'Total': '593.3'}}

# %% [markdown]
# ## total de todos os serviços do cliente por mês

# %%
selecao = [d['Charges'] for d in conta]

# %%
selecao
# Out:
# [{'Monthly': 65.6, 'Total': '593.3'},
#  {'Monthly': 59.9, 'Total': '542.4'},
#  {'Monthly': 73.9, 'Total': '280.85'},
#  {'Monthly': 98.0, 'Total': '1237.85'},
#  {'Monthly': 83.9, 'Total': '267.4'},
#  {'Monthly': 69.4, 'Total': '571.45'},
#  {'Monthly': 109.7, 'Total': '7904.25'},
#  {'Monthly': 84.65, 'Total': '5377.8'},
#  {'Monthly': 48.2, 'Total': '340.35'},
#  {'Monthly': 90.45, 'Total': '5957.9'},
#  {'Monthly': 45.2, 'Total': '2460.55'},
#  {'Monthly': 116.8, 'Total': '8456.75'},
#  {'Monthly': 68.95, 'Total': '351.5'},
#  {'Monthly': 101.3, 'Total': '7261.25'},
#  {'Monthly': 45.05, 'Total': '2560.1'},
#  {'Monthly': 95.75, 'Total': '6849.4'},
#  {'Monthly': 61.25, 'Total': '1993.2'},
#  {'Monthly': 72.1, 'Total': '72.1'},
#  {'Monthly': 62.7, 'Total': '2791.5'},
#  {'Monthly': 25.1, 'Total': '25.1'},
#  {'Monthly': 25.2, 'Total': '1306.3'},
#  {'Monthly': 94.1, 'Total': '1215.6'},
#  {'Monthly': 83.75, 'Total': '1849.95'},
#  {'Monthly': 19.85, 'Total': '57.2'},
# ...

# %%
gastos =[d['Monthly'] for d in selecao]

# %%
mes = pd.DataFrame(gastos, columns = ['gastos_mensais'])

# %%
mes.head(5)
# Out:
#    gastos_mensais
# 0            65.6
# 1            59.9
# 2            73.9
# 3            98.0
# 4            83.9

# %%
mes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gastos_mensais  7267 non-null   float64
# dtypes: float64(1)
# memory usage: 56.9 KB

# %% [markdown]
# ## total gasto pelo cliente

# %%
gastos =[d['Total'] for d in selecao]

# %%
total = pd.DataFrame(gastos, columns = ['gasto_total'])

# %%
total.head(5)
# Out:
#   gasto_total
# 0       593.3
# 1       542.4
# 2      280.85
# 3     1237.85
# 4       267.4

# %%
total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   gasto_total  7267 non-null   object
# dtypes: object(1)
# memory usage: 56.9+ KB

# %% [markdown]
# ## acrescentando e excluindo colunas

# %%
churn_de_clientes_new = pd.read_csv('churn_de_clientes.csv')

# %%
churn_de_clientes_new.head(5)
# Out:
#    cliente_ID Churn  genero  idade_>=_65 tem_parceiro tem_dependentes  \
# 0  0002-ORFBO    No  Female            0          Yes             Yes
# 1  0003-MKNFE    No    Male            0           No              No
# 2  0004-TLHLJ   Yes    Male            0           No              No
# 3  0011-IGKFF   Yes    Male            1          Yes              No
# 4  0013-EXCHZ   Yes  Female            1          Yes              No
#
#   assinatura_provedor_internet assinatura_adicional_seguranca_online  \
# 0                          DSL                                    No
# 1                          DSL                                    No
# 2                  Fiber optic                                    No
# 3                  Fiber optic                                    No
# 4                  Fiber optic                                    No
#
#   assinatura_adicional_backup_online  \
# 0                                Yes
# 1                                 No
# ...

# %%
churn_de_clientes_new['contrato'] = contrato

# %%
churn_de_clientes_new['fatura_online'] = fatura_online

# %%
churn_de_clientes_new['forma_pagamento'] = forma_pagamento

# %%
churn_de_clientes_new['gastos_mensais'] = mes

# %%
churn_de_clientes_new['gasto_total'] = total

# %% [markdown]
# ## criar DataFrame conta

# %%
conta = pd.DataFrame(churn_de_clientes_new[['cliente_ID','contrato','fatura_online','forma_pagamento','gastos_mensais','gasto_total']])

# %%
conta.head(5)
# Out:
#    cliente_ID        contrato fatura_online   forma_pagamento  gastos_mensais  \
# 0  0002-ORFBO        One year           Yes      Mailed check            65.6
# 1  0003-MKNFE  Month-to-month            No      Mailed check            59.9
# 2  0004-TLHLJ  Month-to-month           Yes  Electronic check            73.9
# 3  0011-IGKFF  Month-to-month           Yes  Electronic check            98.0
# 4  0013-EXCHZ  Month-to-month           Yes      Mailed check            83.9
#
#   gasto_total
# 0       593.3
# 1       542.4
# 2      280.85
# 3     1237.85
# 4       267.4

# %%
conta.to_csv('conta.csv', index=False)

# %% [markdown]
# ## atualizar DataFrame churn_de_clientes

# %%
churn_de_clientes_new = pd.DataFrame(churn_de_clientes_new[['cliente_ID','Churn','genero','idade_>=_65','tem_parceiro','tem_dependentes','assinatura_provedor_internet','assinatura_adicional_seguranca_online','assinatura_adicional_backup_online','assinatura_adicional_protecao_dispositivo','assinatura_adicional_suporte_tecnico_menos_tempo_espera','assinatura_TV_cabo','assinatura_streaming_filmes','contrato','fatura_online','forma_pagamento','gastos_mensais','gasto_total']])

# %%
churn_de_clientes_new.head(5)
# Out:
#    cliente_ID Churn  genero  idade_>=_65 tem_parceiro tem_dependentes  \
# 0  0002-ORFBO    No  Female            0          Yes             Yes
# 1  0003-MKNFE    No    Male            0           No              No
# 2  0004-TLHLJ   Yes    Male            0           No              No
# 3  0011-IGKFF   Yes    Male            1          Yes              No
# 4  0013-EXCHZ   Yes  Female            1          Yes              No
#
#   assinatura_provedor_internet assinatura_adicional_seguranca_online  \
# 0                          DSL                                    No
# 1                          DSL                                    No
# 2                  Fiber optic                                    No
# 3                  Fiber optic                                    No
# 4                  Fiber optic                                    No
#
#   assinatura_adicional_backup_online  \
# 0                                Yes
# 1                                 No
# ...

# %%
churn_de_clientes_new.to_csv('churn_de_clientes.csv', index=False)

# %%
churn_de_clientes_new.shape
# Out:
# (7267, 18)

# %% [markdown]
# ## Print

# %%
print('INFORMAÇÕES SOBRE CONTA')
print('##'*25 + '\n')
print(f'Contratos:\n\n  Contrato de 1 Ano: {len(contrato_one_year)}\n\n  Contrato de 2 Anos: {len(contrato_two_year)}\n\n  Contrato de Mês a Mês: {len(contrato_month)}\n\nTotal: {soma_contrato}\n')
print('--'*25 + '\n')
print(f'Receber fatura online:\n\n  Sim: {len(fatura_online_yes)}\n\n  Não: {len(fatura_online_not)}\n\nTotal: {soma_fatura}\n')
print('--'*25 + '\n')
print(f'Forma de Pagamento:\n\n  Cheque Enviado: {len(forma_pagamento_mailed)}\n\n  Cheque Eletrônico: {len(forma_pagamento_electronic)}\n\n  Cartão de Crédito(automático): {len(forma_pagamento_card)}\n\n  Transferência Bancaria(automático): {len(forma_pagamento_bank)}\n\nTotal: {soma_pagamento}\n')
# Out:
# INFORMAÇÕES SOBRE CONTA
# ##################################################
#
# Contratos:
#
#   Contrato de 1 Ano: 1519
#
#   Contrato de 2 Anos: 1743
#
#   Contrato de Mês a Mês: 4005
#
# Total: 7267
#
# --------------------------------------------------
#
# Receber fatura online:
#
#   Sim: 4311
#
#   Não: 2956
#
# Total: 7267
#
# --------------------------------------------------
#
# Forma de Pagamento:
#
#   Cheque Enviado: 1665
#
#   Cheque Eletrônico: 2445
#
#   Cartão de Crédito(automático): 1568
#
#   Transferência Bancaria(automático): 1589
#
# Total: 7267
